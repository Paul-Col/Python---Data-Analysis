# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
#create sample data
cols = ['open', 'close', 'date']

apple_stocks = pd.read_csv('AAPL.csv', usecols=cols, index_col='date', parse_dates=['date'])
apple_stocks
# Out:
#                              close    open
# date
# 2015-05-27 00:00:00+00:00  132.045  130.34
# 2015-05-28 00:00:00+00:00  131.780  131.86
# 2015-05-29 00:00:00+00:00  130.280  131.23
# 2015-06-01 00:00:00+00:00  130.535  131.20
# 2015-06-02 00:00:00+00:00  129.960  129.86
# ...                            ...     ...
# 2020-05-18 00:00:00+00:00  314.960  313.17
# 2020-05-19 00:00:00+00:00  313.140  315.03
# 2020-05-20 00:00:00+00:00  319.230  316.68
# 2020-05-21 00:00:00+00:00  316.850  318.66
# 2020-05-22 00:00:00+00:00  318.890  315.77
#
# [1258 rows x 2 columns]

# %%
#create sample plot
apple_stocks.plot()
# Out:
# <Axes: xlabel='date'>

# %%
#import data to create line plot
cols = ['date', 'high', 'low', 'open', 'close']

ap_stocks = pd.read_csv('AAPL.csv', usecols=cols, index_col='date', parse_dates=['date'])
ap_stocks
# Out:
#                              close     high       low    open
# date
# 2015-05-27 00:00:00+00:00  132.045  132.260  130.0500  130.34
# 2015-05-28 00:00:00+00:00  131.780  131.950  131.1000  131.86
# 2015-05-29 00:00:00+00:00  130.280  131.450  129.9000  131.23
# 2015-06-01 00:00:00+00:00  130.535  131.390  130.0500  131.20
# 2015-06-02 00:00:00+00:00  129.960  130.655  129.3200  129.86
# ...                            ...      ...       ...     ...
# 2020-05-18 00:00:00+00:00  314.960  316.500  310.3241  313.17
# 2020-05-19 00:00:00+00:00  313.140  318.520  313.0100  315.03
# 2020-05-20 00:00:00+00:00  319.230  319.520  316.2000  316.68
# 2020-05-21 00:00:00+00:00  316.850  320.890  315.8700  318.66
# 2020-05-22 00:00:00+00:00  318.890  319.230  315.3500  315.77
#
# [1258 rows x 4 columns]

# %%
#create plot showing all data for given month
ap_stocks.loc['2016-05'].plot()
# Out:
# <Axes: xlabel='date'>

# %%
#plot for close price only
ap_stocks.plot(y='close')
# Out:
# <Axes: xlabel='date'>

# %%
#plot for open and close price in given month
ap_stocks.loc['2016-05'].plot(y=['open', 'close'])
# Out:
# <Axes: xlabel='date'>

# %%
#create subplots for each
ap_stocks.plot(subplots=True)
# Out:
# array([<Axes: xlabel='date'>, <Axes: xlabel='date'>,
#        <Axes: xlabel='date'>, <Axes: xlabel='date'>], dtype=object)

# %%
#use figsize to change plot size
ap_stocks.plot(subplots=True, figsize=(15,10))
# Out:
# array([<Axes: xlabel='date'>, <Axes: xlabel='date'>,
#        <Axes: xlabel='date'>, <Axes: xlabel='date'>], dtype=object)

# %%
#add labels to plot
ap_stocks.plot()
plt.title('Apple Stock Price')
plt.legend(loc='best')
plt.xlabel('Years')
plt.ylabel('Price')
plt.grid()

# %%
ap_stocks.loc['2016-05'].plot(y='close', c='g', linewidth=5, linestyle=':')
# Out:
# <Axes: xlabel='date'>

# %%
#import data to create bar plot
cols = ['date', 'high', 'low', 'open', 'close']

app_stocks = pd.read_csv('AAPL.csv', usecols=cols, index_col='date', parse_dates=['date'])
app_stocks
# Out:
#                              close     high       low    open
# date
# 2015-05-27 00:00:00+00:00  132.045  132.260  130.0500  130.34
# 2015-05-28 00:00:00+00:00  131.780  131.950  131.1000  131.86
# 2015-05-29 00:00:00+00:00  130.280  131.450  129.9000  131.23
# 2015-06-01 00:00:00+00:00  130.535  131.390  130.0500  131.20
# 2015-06-02 00:00:00+00:00  129.960  130.655  129.3200  129.86
# ...                            ...      ...       ...     ...
# 2020-05-18 00:00:00+00:00  314.960  316.500  310.3241  313.17
# 2020-05-19 00:00:00+00:00  313.140  318.520  313.0100  315.03
# 2020-05-20 00:00:00+00:00  319.230  319.520  316.2000  316.68
# 2020-05-21 00:00:00+00:00  316.850  320.890  315.8700  318.66
# 2020-05-22 00:00:00+00:00  318.890  319.230  315.3500  315.77
#
# [1258 rows x 4 columns]

# %%
#get the mean
months = app_stocks.resample('a').mean().round(2)
months.index = months.index.year
months
# Out:
# C:\Users\Paul\AppData\Local\Temp\ipykernel_31724\2075632387.py:1: FutureWarning: 'a' is deprecated and will be removed in a future version, please use 'YE' instead.
#   months = app_stocks.resample('a').mean().round(2)
#        close    high     low    open
# date
# 2015  117.83  119.03  116.65  117.93
# 2016  104.60  105.43  103.69  104.51
# 2017  150.55  151.41  149.49  150.45
# 2018  189.05  190.99  187.18  189.11
# 2019  208.26  209.83  206.27  207.87
# 2020  291.79  295.89  287.02  290.75

# %%
#plot bar graph
months.plot(y='high', kind='bar')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %%
#turn bars horizontal
months.plot(y='high', kind='barh')
plt.xlabel('year')
# Out:
# Text(0.5, 0, 'year')

# %%
#multiple bars and changing colours
months.plot(y=['high', 'low'], kind='bar', color=('orange', 'green'))
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %%
#import data to create histograms
exams = pd.read_csv('exams.csv')
exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group A                 high school      standard
# 1    female        group D            some high school  free/reduced
# 2      male        group E                some college  free/reduced
# 3      male        group B                 high school      standard
# 4      male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#create total column
exams['total'] = exams['math score'] + exams['reading score'] + exams['writing score']
exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group A                 high school      standard
# 1    female        group D            some high school  free/reduced
# 2      male        group E                some college  free/reduced
# 3      male        group B                 high school      standard
# 4      male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score  total
# ...

# %%
#create histogram of total
exams.plot(y='total', kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
#change number of bins and change colour
exams.plot(y='total', kind='hist', bins=25, color='purple')
# Out:
# <Axes: ylabel='Frequency'>

# %%
exams['total'].hist(grid=True, bins=20, color='skyblue')
# Out:
# <Axes: >

# %%
#import data to create piecharts
rich = pd.read_csv('TopRichestInWorld.csv')
rich
# Out:
#                          Name          NetWorth  Age Country/Territory  \
# 0                   Elon Musk  $219,000,000,000   50     United States
# 1                  Jeff Bezos  $171,000,000,000   58     United States
# 2    Bernard Arnault & family  $158,000,000,000   73            France
# 3                  Bill Gates  $129,000,000,000   66     United States
# 4              Warren Buffett  $118,000,000,000   91     United States
# ..                        ...               ...  ...               ...
# 96           Vladimir Potanin   $17,300,000,000   61            Russia
# 97       Harold Hamm & family   $17,200,000,000   76     United States
# 98               Sun Piaoyang   $17,100,000,000   63             China
# 99         Luo Liguo & family   $17,000,000,000   66             China
# 100                 Peter Woo   $17,000,000,000   75         Hong Kong
#
#                  Source               Industry
# 0         Tesla, SpaceX             Automotive
# ...

# %%
#create counts of each industry
industry = rich['Industry'].value_counts()
industry
# Out:
# Industry
# Fashion & Retail         18
# Technology               15
# Finance & Investments    13
# Metals & Mining           9
# Food & Beverage           8
# Automotive                7
# Diversified               6
# Manufacturing             5
# Healthcare                5
# Media & Entertainment     4
# Real Estate               3
# Telecom                   2
# Logistics                 2
# Energy                    2
# Gambling & Casinos        1
# Service                   1
# Name: count, dtype: int64

# %%
#plot pie chart
plt.pie(x=industry.values, labels=industry.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x231cd8ebfb0>,
# ...
#  [Text(0.9320461635394063, 0.5842002644911028, 'Fashion & Retail'),
#   Text(-0.01710703950300457, 1.099866968864618, 'Technology'),
#   Text(-0.8523428619674444, 0.6953500166485556, 'Finance & Investments'),
#   Text(-1.0999999999999954, -1.0298943258065002e-07, 'Metals & Mining'),
#   Text(-0.9497638199575874, -0.5549312446597071, 'Food & Beverage'),
#   Text(-0.5986245075706607, -0.922848145111526, 'Automotive'),
#   Text(-0.18726779260124032, -1.0839422373236773, 'Diversified'),
#   Text(0.18726803363047703, -1.0839421956821196, 'Manufacturing'),
#   Text(0.5100299960839939, -0.9746124373793726, 'Healthcare'),
#   Text(0.7594621119777382, -0.7957495211876119, 'Media & Entertainment'),
#   Text(0.9134268495401443, -0.6129040630793424, 'Real Estate'),
#   Text(0.9973399133690894, -0.464018423342153, 'Telecom'),
#   Text(1.047214455404698, -0.336662864586283, 'Logistics'),
#   Text(1.080898795145707, -0.20410241216741928, 'Energy'),
# ...

# %%
#display only top 10 industries
labels = industry.index[:10]
values = industry.values[:10]

plt.pie(x=values, labels=labels, autopct='%.2f%%')
plt.show()

# %%
#specify colours, if not enough it will loop through
plt.figure()
plt.pie(x=values, labels=labels, colors=('skyblue','darkblue'))
# Out:
# ([<matplotlib.patches.Wedge at 0x231d302f650>,
# ...
#  [Text(0.8899186877588753, 0.6465637858537406, 'Fashion & Retail'),
#   Text(-0.2287028968371194, 1.0759623529558597, 'Technology'),
#   Text(-1.0199022687445178, 0.4120671816703988, 'Finance & Investments'),
#   Text(-1.0199022012286048, -0.41206734877814155, 'Metals & Mining'),
#   Text(-0.6151120975257726, -0.9119413947603456, 'Food & Beverage'),
#   Text(-0.0767319881291848, -1.09732046458532, 'Automotive'),
#   Text(0.41206739652320884, -1.0199021819383391, 'Diversified'),
#   Text(0.7641243287151949, -0.7912736633210743, 'Manufacturing'),
#   Text(0.9886735260496547, -0.48220810744795956, 'Healthcare'),
#   Text(1.0892949001814978, -0.1530902362614323, 'Media & Entertainment')])
