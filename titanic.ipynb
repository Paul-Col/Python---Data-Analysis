# %%
import pandas as pd

# %%
#load excel data
titanic = pd.read_excel('titanic3.xlsx')
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
#check what datatypes are used and whta values are present
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
#create dataframe of passengers index by name using .loc
passengers =pd.read_excel('titanic3.xlsx', index_col = 'name')
passengers
# Out:
#                                                  pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                         1         1  female
# Allison, Master. Hudson Trevor                        1         1    male
# Allison, Miss. Helen Loraine                          1         0  female
# Allison, Mr. Hudson Joshua Creighton                  1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1         0  female
# ...                                                 ...       ...     ...
# Zabour, Miss. Hileni                                  3         0  female
# Zabour, Miss. Thamine                                 3         0  female
# Zakarian, Mr. Mapriededer                             3         0    male
# Zakarian, Mr. Ortin                                   3         0    male
# Zimmerman, Mr. Leo                                    3         0    male
#
#                                                      age  sibsp  parch  \
# ...

# %%
#sort pasenger names to make selecting lines faster
passengers.sort_index(inplace=True)
passengers
# Out:
#                                                pclass  survived     sex   age  \
# name
# Abbing, Mr. Anthony                                 3         0    male  42.0
# Abbott, Master. Eugene Joseph                       3         0    male  13.0
# Abbott, Mr. Rossmore Edward                         3         0    male  16.0
# Abbott, Mrs. Stanton (Rosa Hunt)                    3         1  female  35.0
# Abelseth, Miss. Karen Marie                         3         1  female  16.0
# ...                                               ...       ...     ...   ...
# del Carlo, Mrs. Sebastiano (Argenia Genovesi)       2         1  female  24.0
# van Billiard, Master. James William                 3         0    male   NaN
# van Billiard, Master. Walter John                   3         0    male  11.5
# van Billiard, Mr. Austin Blyler                     3         0    male  40.5
# van Melkebeke, Mr. Philemon                         3         0    male   NaN
#
# ...

# %%
#return information on given passenger
passengers.loc['Abbott, Mr. Rossmore Edward']
# Out:
# pclass                         3
# survived                       0
# sex                         male
# age                         16.0
# sibsp                          1
# parch                          1
# ticket                 C.A. 2673
# fare                       20.25
# cabin                        NaN
# embarked                       S
# boat                         NaN
# body                       190.0
# home.dest    East Providence, RI
# Name: Abbott, Mr. Rossmore Edward, dtype: object

# %%
#return information on more than one passenger
passengers.loc[['Abbott, Mr. Rossmore Edward', 'Zabour, Miss. Hileni']]
# Out:
#                              pclass  survived     sex   age  sibsp  parch  \
# name
# Abbott, Mr. Rossmore Edward       3         0    male  16.0      1      1
# Zabour, Miss. Hileni              3         0  female  14.5      1      0
#
#                                 ticket     fare cabin embarked boat   body  \
# name
# Abbott, Mr. Rossmore Edward  C.A. 2673  20.2500   NaN        S  NaN  190.0
# Zabour, Miss. Hileni              2665  14.4542   NaN        C  NaN  328.0
#
#                                        home.dest
# name
# Abbott, Mr. Rossmore Edward  East Providence, RI
# Zabour, Miss. Hileni                         NaN

# %%
#these entries are duplicates
passengers.loc['Kelly, Mr. James']
# Out:
#                   pclass  survived   sex   age  sibsp  parch  ticket    fare  \
# name
# Kelly, Mr. James       3         0  male  34.5      0      0  330911  7.8292
# Kelly, Mr. James       3         0  male  44.0      0      0  363592  8.0500
#
#                  cabin embarked boat  body home.dest
# name
# Kelly, Mr. James   NaN        Q  NaN  70.0       NaN
# Kelly, Mr. James   NaN        S  NaN   NaN       NaN

# %%
#return passengers between twp cortect values
passengers.loc['Allen, Miss. Elisabeth Waton' : 'Allison, Miss. Helen Loraine']
# Out:
#                                 pclass  survived     sex      age  sibsp  \
# name
# Allen, Mr. William Henry             3         0    male  35.0000      0
# Allison, Master. Hudson Trevor       1         1    male   0.9167      1
# Allison, Miss. Helen Loraine         1         0  female   2.0000      1
#
#                                 parch  ticket    fare    cabin embarked boat  \
# name
# Allen, Mr. William Henry            0  373450    8.05      NaN        S  NaN
# Allison, Master. Hudson Trevor      2  113781  151.55  C22 C26        S   11
# Allison, Miss. Helen Loraine        2  113781  151.55  C22 C26        S  NaN
#
#                                 body  \
# name
# Allen, Mr. William Henry         NaN
# Allison, Master. Hudson Trevor   NaN
# Allison, Miss. Helen Loraine     NaN
#
#                                                                         home.dest
# name
# Allen, Mr. William Henry        Lower Clapton, Middlesex or Erdington, Birmingham
# ...

# %%
#return value of specific column for passenger
passengers.loc['Allison, Miss. Helen Loraine', 'fare']
# Out:
# 151.55

# %%
#return a series for all values of columns of given passenger
passengers.loc['Allison, Miss. Helen Loraine', ['fare','sex','cabin']]
# Out:
# fare      151.55
# sex       female
# cabin    C22 C26
# Name: Allison, Miss. Helen Loraine, dtype: object

# %%
#returns datframe for all passengers in list
names = ['Allen, Miss. Elisabeth Walton', 'Allison, Miss. Helen Loraine']
passengers.loc[names, ['fare','sex','cabin']]
# Out:
#                                    fare     sex    cabin
# name
# Allen, Miss. Elisabeth Walton  211.3375  female       B5
# Allison, Miss. Helen Loraine   151.5500  female  C22 C26

# %%
#use of iloc in pandas

index = pd.read_excel('titanic3.xlsx',usecols=['name','sex','age','pclass','fare'])
index
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age      fare
# 0     29.0000  211.3375
# 1      0.9167  151.5500
# 2      2.0000  151.5500
# 3     30.0000  151.5500
# ...

# %%
#find using index
index.loc[1308]
# Out:
# pclass                     3
# name      Zimmerman, Mr. Leo
# sex                     male
# age                     29.0
# fare                   7.875
# Name: 1308, dtype: object

# %%
#delect row using integer location
index.iloc[23]
# Out:
# pclass                        1
# name      Bidois, Miss. Rosalie
# sex                      female
# age                        42.0
# fare                    227.525
# Name: 23, dtype: object

# %%
#use slicing to return first 5
index.iloc[0:5]
# Out:
#    pclass                                             name     sex      age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1       1                   Allison, Master. Hudson Trevor    male   0.9167
# 2       1                     Allison, Miss. Helen Loraine  female   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
#
#        fare
# 0  211.3375
# 1  151.5500
# 2  151.5500
# 3  151.5500
# 4  151.5500

# %%
#use slicing with a step of 2 to return every other record
index.iloc[0:10:2]
# Out:
#    pclass                                             name     sex   age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0
# 2       1                     Allison, Miss. Helen Loraine  female   2.0
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0
# 6       1                Andrews, Miss. Kornelia Theodosia  female  63.0
# 8       1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.0
#
#        fare
# 0  211.3375
# 2  151.5500
# 4  151.5500
# 6   77.9583
# 8   51.4792

# %%
#return at given indexs
index.iloc[[100,200,300,400]]
# Out:
#      pclass                                             name     sex   age  \
# 100       1     Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")    male  49.0
# 200       1                     McCaffry, Mr. Thomas Francis    male  46.0
# 300       1                        Van der hoef, Mr. Wyckoff    male  61.0
# 400       2  Drew, Mrs. James Vivian (Lulu Thorne Christian)  female  34.0
#
#         fare
# 100  56.9292
# 200  75.2417
# 300  33.5000
# 400  32.5000

# %%
#negative index to return last 3 rows
index.iloc[-3:]
# Out:
#       pclass                       name   sex   age   fare
# 1306       3  Zakarian, Mr. Mapriededer  male  26.5  7.225
# 1307       3        Zakarian, Mr. Ortin  male  27.0  7.225
# 1308       3         Zimmerman, Mr. Leo  male  29.0  7.875

# %%
#negative index to return individual row
index.iloc[-3]
# Out:
# pclass                            3
# name      Zakarian, Mr. Mapriededer
# sex                            male
# age                            26.5
# fare                          7.225
# Name: 1306, dtype: object

# %%
#return value from row 5 and column 3
index.iloc[5,3]
# Out:
# 48.0

# %%
#reurn vslues from rows 4,,5,6 in column 3
index.iloc[[4,5,6],3]
# Out:
# 4    25.0
# 5    48.0
# 6    63.0
# Name: age, dtype: float64

# %%
#return series of row 5 and columns 0,1,2
index.iloc[5,[0,1,2]]
# Out:
# pclass                      1
# name      Anderson, Mr. Harry
# sex                      male
# Name: 5, dtype: object

# %%
#return dataframe of selected rows and columns
index.iloc[[4,5,6],[0,1,2]]
# Out:
#    pclass                                             name     sex
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1                              Anderson, Mr. Harry    male
# 6       1                Andrews, Miss. Kornelia Theodosia  female

# %%
#return all rows
index.iloc[:,[0,1,2]]
# Out:
#       pclass                                             name     sex
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
# [1309 rows x 3 columns]

# %%
#return all columns for given rows
index.iloc[[1,2,3],:]
# Out:
#    pclass                                  name     sex      age    fare
# 1       1        Allison, Master. Hudson Trevor    male   0.9167  151.55
# 2       1          Allison, Miss. Helen Loraine  female   2.0000  151.55
# 3       1  Allison, Mr. Hudson Joshua Creighton    male  30.0000  151.55

# %%
cols = ['name','fare','survived','pclass','age','sex']
element = pd.read_excel('titanic3.xlsx', index_col='name', usecols=cols)
element
# Out:
#                                                  pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                         1         1  female
# Allison, Master. Hudson Trevor                        1         1    male
# Allison, Miss. Helen Loraine                          1         0  female
# Allison, Mr. Hudson Joshua Creighton                  1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1         0  female
# ...                                                 ...       ...     ...
# Zabour, Miss. Hileni                                  3         0  female
# Zabour, Miss. Thamine                                 3         0  female
# Zakarian, Mr. Mapriededer                             3         0    male
# Zakarian, Mr. Ortin                                   3         0    male
# Zimmerman, Mr. Leo                                    3         0    male
#
#                                                      age      fare
# name
# ...

# %%
#reduce every fare by half
element['fare'] / 2
# Out:
# 0       105.66875
# 1        75.77500
# 2        75.77500
# 3        75.77500
# 4        75.77500
#           ...
# 1304      7.22710
# 1305      7.22710
# 1306      3.61250
# 1307      3.61250
# 1308      3.93750
# Name: fare, Length: 1309, dtype: float64

# %%
#create new column for the reduced fare
element['reduced'] = (element['fare'] / 2).round()
element
# Out:
#                                                  pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                         1         1  female
# Allison, Master. Hudson Trevor                        1         1    male
# Allison, Miss. Helen Loraine                          1         0  female
# Allison, Mr. Hudson Joshua Creighton                  1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1         0  female
# ...                                                 ...       ...     ...
# Zabour, Miss. Hileni                                  3         0  female
# Zabour, Miss. Thamine                                 3         0  female
# Zakarian, Mr. Mapriededer                             3         0    male
# Zakarian, Mr. Ortin                                   3         0    male
# Zimmerman, Mr. Leo                                    3         0    male
#
# ...

# %%
#find all males
element['sex'] == 'male'
# Out:
# name
# Allen, Miss. Elisabeth Walton                      False
# Allison, Master. Hudson Trevor                      True
# Allison, Miss. Helen Loraine                       False
# Allison, Mr. Hudson Joshua Creighton                True
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    False
#                                                    ...
# Zabour, Miss. Hileni                               False
# Zabour, Miss. Thamine                              False
# Zakarian, Mr. Mapriededer                           True
# Zakarian, Mr. Ortin                                 True
# Zimmerman, Mr. Leo                                  True
# Name: sex, Length: 1309, dtype: bool

# %%
#filter all males
element[element['sex'] == 'male']
# Out:
#                                       pclass  survived   sex      age  \
# name
# Allison, Master. Hudson Trevor             1         1  male   0.9167
# Allison, Mr. Hudson Joshua Creighton       1         0  male  30.0000
# Anderson, Mr. Harry                        1         1  male  48.0000
# Andrews, Mr. Thomas Jr                     1         0  male  39.0000
# Artagaveytia, Mr. Ramon                    1         0  male  71.0000
# ...                                      ...       ...   ...      ...
# Yousif, Mr. Wazli                          3         0  male      NaN
# Yousseff, Mr. Gerious                      3         0  male      NaN
# Zakarian, Mr. Mapriededer                  3         0  male  26.5000
# Zakarian, Mr. Ortin                        3         0  male  27.0000
# Zimmerman, Mr. Leo                         3         0  male  29.0000
#
#                                           fare  reduced
# name
# Allison, Master. Hudson Trevor        151.5500     76.0
# ...

# %%
#create mask to make it more readable
male_mask = element['sex'] == 'male'
element[male_mask]
# Out:
#                                       pclass  survived   sex      age  \
# name
# Allison, Master. Hudson Trevor             1         1  male   0.9167
# Allison, Mr. Hudson Joshua Creighton       1         0  male  30.0000
# Anderson, Mr. Harry                        1         1  male  48.0000
# Andrews, Mr. Thomas Jr                     1         0  male  39.0000
# Artagaveytia, Mr. Ramon                    1         0  male  71.0000
# ...                                      ...       ...   ...      ...
# Yousif, Mr. Wazli                          3         0  male      NaN
# Yousseff, Mr. Gerious                      3         0  male      NaN
# Zakarian, Mr. Mapriededer                  3         0  male  26.5000
# Zakarian, Mr. Ortin                        3         0  male  27.0000
# Zimmerman, Mr. Leo                         3         0  male  29.0000
#
#                                           fare  reduced
# name
# Allison, Master. Hudson Trevor        151.5500     76.0
# ...

# %%
#create a mask for aged over 65
age_mask = element['age'] > 65
element[age_mask]
# Out:
#                                                     pclass  survived     sex  \
# name
# Artagaveytia, Mr. Ramon                                  1         0    male
# Barkworth, Mr. Algernon Henry Wilson                     1         1    male
# Cavendish, Mrs. Tyrell William (Julia Florence ...       1         1  female
# Crosby, Capt. Edward Gifford                             1         0    male
# Goldschmidt, Mr. George B                                1         0    male
# Straus, Mr. Isidor                                       1         0    male
# Mitchell, Mr. Henry Michael                              2         0    male
# Wheadon, Mr. Edward H                                    2         0    male
# Connors, Mr. Patrick                                     3         0    male
# Svensson, Mr. Johan                                      3         0    male
#
#                                                      age      fare  reduced
# name
# ...

# %%
#filter all females in 1st class that survived
female_mask = element['sex'] == 'female'
first_mask = element['pclass'] == 1
survived_mask = element['survived'] ==1

element[female_mask & first_mask & survived_mask]
# Out:
#                                                    pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                           1         1  female
# Andrews, Miss. Kornelia Theodosia                       1         1  female
# Appleton, Mrs. Edward Dale (Charlotte Lamson)           1         1  female
# Astor, Mrs. John Jacob (Madeleine Talmadge Force)       1         1  female
# Aubart, Mme. Leontine Pauline                           1         1  female
# ...                                                   ...       ...     ...
# Wick, Mrs. George Dennick (Mary Hitchcock)              1         1  female
# Widener, Mrs. George Dunton (Eleanor Elkins)            1         1  female
# Willard, Miss. Constance                                1         1  female
# Wilson, Miss. Helen Alice                               1         1  female
# Young, Miss. Marie Grice                                1         1  female
#
# ...

# %%
#filter anyone under age of 21 and paid a fare of more than 200
richchild_mask  = (element['age'] < 21) & (element['fare'] > 200)
rich = element[richchild_mask]

#find top five
rich.nlargest(n=5, columns=['age','fare'])
# Out:
#                                                    pclass  survived     sex  \
# name
# Fortune, Mr. Charles Alexander                          1         0    male
# Ryerson, Miss. Emily Borie                              1         1  female
# Astor, Mrs. John Jacob (Madeleine Talmadge Force)       1         1  female
# Madill, Miss. Georgette Alexandra                       1         1  female
# Ryerson, Master. John Borie                             1         1    male
#
#                                                     age      fare  reduced
# name
# Fortune, Mr. Charles Alexander                     19.0  263.0000    132.0
# Ryerson, Miss. Emily Borie                         18.0  262.3750    131.0
# Astor, Mrs. John Jacob (Madeleine Talmadge Force)  18.0  227.5250    114.0
# Madill, Miss. Georgette Alexandra                  15.0  211.3375    106.0
# Ryerson, Master. John Borie                        13.0  262.3750    131.0

# %%
#filter everyone under age of 21 OR female and survived
survived_mask = element['survived'] == 1
femalke_mask = element['sex'] == 'female'
age_mask = element['age'] <= 21

element[(age_mask | female_mask) & survived_mask]
# Out:
#                                                    pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                           1         1  female
# Allison, Master. Hudson Trevor                          1         1    male
# Andrews, Miss. Kornelia Theodosia                       1         1  female
# Appleton, Mrs. Edward Dale (Charlotte Lamson)           1         1  female
# Astor, Mrs. John Jacob (Madeleine Talmadge Force)       1         1  female
# ...                                                   ...       ...     ...
# Turja, Miss. Anna Sofia                                 3         1  female
# Turkula, Mrs. (Hedwig)                                  3         1  female
# Whabee, Mrs. George Joseph (Shawneene Abi-Saab)         3         1  female
# Wilkes, Mrs. James (Ellen Needs)                        3         1  female
# Yasbeck, Mrs. Antoni (Selini Alexander)                 3         1  female
#
# ...

# %%
#filter people between 20 and 25
upper_mask = element['age'] >= 20
lower_mask = element['age'] <= 25

element[upper_mask & lower_mask]
# Out:
#                                                  pclass  survived     sex  \
# name
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1         0  female
# Aubart, Mme. Leontine Pauline                         1         1  female
# Baxter, Mr. Quigg Edmond                              1         0    male
# Birnbaum, Mr. Jakob                                   1         0    male
# Bishop, Mr. Dickinson H                               1         1    male
# ...                                                 ...       ...     ...
# Vendel, Mr. Olof Edvin                                3         0    male
# Vovk, Mr. Janko                                       3         0    male
# Waelens, Mr. Achille                                  3         0    male
# Wiklund, Mr. Karl Johan                               3         0    male
# Windelov, Mr. Einar                                   3         0    male
#
#                                                   age      fare  reduced
# ...

# %%
#easier way is to use between method
youngadult_mask = element['age'].between(20,25)
element[youngadult_mask]
# Out:
#                                                  pclass  survived     sex  \
# name
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1         0  female
# Aubart, Mme. Leontine Pauline                         1         1  female
# Baxter, Mr. Quigg Edmond                              1         0    male
# Birnbaum, Mr. Jakob                                   1         0    male
# Bishop, Mr. Dickinson H                               1         1    male
# ...                                                 ...       ...     ...
# Vendel, Mr. Olof Edvin                                3         0    male
# Vovk, Mr. Janko                                       3         0    male
# Waelens, Mr. Achille                                  3         0    male
# Wiklund, Mr. Karl Johan                               3         0    male
# Windelov, Mr. Einar                                   3         0    male
#
#                                                   age      fare  reduced
# ...

# %%
#select passengers in 1st or 2nd class
first_mask = element['pclass'] == 1
second_mask = element['pclass'] == 2

element[first_mask | second_mask]
# Out:
#                                                  pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                         1         1  female
# Allison, Master. Hudson Trevor                        1         1    male
# Allison, Miss. Helen Loraine                          1         0  female
# Allison, Mr. Hudson Joshua Creighton                  1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1         0  female
# ...                                                 ...       ...     ...
# Wheeler, Mr. Edwin "Frederick"                        2         0    male
# Wilhelms, Mr. Charles                                 2         1    male
# Williams, Mr. Charles Eugene                          2         1    male
# Wright, Miss. Marion                                  2         1  female
# Yrois, Miss. Henriette ("Mrs Harbeck")                2         0  female
#
# ...

# %%
#easier way 
element['pclass'].isin([1,2])
# Out:
# name
# Allen, Miss. Elisabeth Walton                       True
# Allison, Master. Hudson Trevor                      True
# Allison, Miss. Helen Loraine                        True
# Allison, Mr. Hudson Joshua Creighton                True
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)     True
#                                                    ...
# Zabour, Miss. Hileni                               False
# Zabour, Miss. Thamine                              False
# Zakarian, Mr. Mapriededer                          False
# Zakarian, Mr. Ortin                                False
# Zimmerman, Mr. Leo                                 False
# Name: pclass, Length: 1309, dtype: bool

# %%
#checks if a element is null in a column
element['age'].isnull()
# Out:
# name
# Allen, Miss. Elisabeth Walton                      False
# Allison, Master. Hudson Trevor                     False
# Allison, Miss. Helen Loraine                       False
# Allison, Mr. Hudson Joshua Creighton               False
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    False
#                                                    ...
# Zabour, Miss. Hileni                               False
# Zabour, Miss. Thamine                               True
# Zakarian, Mr. Mapriededer                          False
# Zakarian, Mr. Ortin                                False
# Zimmerman, Mr. Leo                                 False
# Name: age, Length: 1309, dtype: bool

# %%
#checks if an elemnet is not null
element['age'].notnull()
# Out:
# name
# Allen, Miss. Elisabeth Walton                       True
# Allison, Master. Hudson Trevor                      True
# Allison, Miss. Helen Loraine                        True
# Allison, Mr. Hudson Joshua Creighton                True
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)     True
#                                                    ...
# Zabour, Miss. Hileni                                True
# Zabour, Miss. Thamine                              False
# Zakarian, Mr. Mapriededer                           True
# Zakarian, Mr. Ortin                                 True
# Zimmerman, Mr. Leo                                  True
# Name: age, Length: 1309, dtype: bool

# %%
#create mask for all unknown ages
unknown_age_mask = element['age'].isnull()
element[unknown_age_mask]
# Out:
#                                                     pclass  survived     sex  \
# name
# Baumann, Mr. John D                                      1         0    male
# Bradley, Mr. George ("George Arthur Brayton")            1         1    male
# Brewe, Dr. Arthur Jackson                                1         0    male
# Cairns, Mr. Alexander                                    1         0    male
# Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genevi...       1         1  female
# ...                                                    ...       ...     ...
# Williams, Mr. Howard Hugh "Harry"                        3         0    male
# Wiseman, Mr. Phillippe                                   3         0    male
# Yousif, Mr. Wazli                                        3         0    male
# Yousseff, Mr. Gerious                                    3         0    male
# Zabour, Miss. Thamine                                    3         0  female
#
# ...

# %%
#create mask for all known ages
known_age_mask = element['age'].notnull()
element[known_age_mask]
# Out:
#                                                  pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                         1         1  female
# Allison, Master. Hudson Trevor                        1         1    male
# Allison, Miss. Helen Loraine                          1         0  female
# Allison, Mr. Hudson Joshua Creighton                  1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1         0  female
# ...                                                 ...       ...     ...
# Youseff, Mr. Gerious                                  3         0    male
# Zabour, Miss. Hileni                                  3         0  female
# Zakarian, Mr. Mapriededer                             3         0    male
# Zakarian, Mr. Ortin                                   3         0    male
# Zimmerman, Mr. Leo                                    3         0    male
#
# ...

# %%
#renaming columns

#get column names
element.columns
# Out:
# Index(['pclass', 'survived', 'sex', 'age', 'fare', 'reduced'], dtype='object')

# %%
#get column name at index
element.columns[0]
# Out:
# 'pclass'

# %%
#rename column
element.rename(columns={'fare' : 'ticket price', 'pclass' : 'class'}, inplace=True)
element
# Out:
#                                                  class  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                        1         1  female
# Allison, Master. Hudson Trevor                       1         1    male
# Allison, Miss. Helen Loraine                         1         0  female
# Allison, Mr. Hudson Joshua Creighton                 1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)      1         0  female
# ...                                                ...       ...     ...
# Zabour, Miss. Hileni                                 3         0  female
# Zabour, Miss. Thamine                                3         0  female
# Zakarian, Mr. Mapriededer                            3         0    male
# Zakarian, Mr. Ortin                                  3         0    male
# Zimmerman, Mr. Leo                                   3         0    male
#
#                                                      age  ticket price  \
# name
# ...

# %%
#rename element in row
element.rename({'Allen, Miss. Elisabeth Walton' : 'Passenger 1'})
# Out:
#                                                  class  survived     sex  \
# name
# Passenger 1                                          1         1  female
# Allison, Master. Hudson Trevor                       1         1    male
# Allison, Miss. Helen Loraine                         1         0  female
# Allison, Mr. Hudson Joshua Creighton                 1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)      1         0  female
# ...                                                ...       ...     ...
# Zabour, Miss. Hileni                                 3         0  female
# Zabour, Miss. Thamine                                3         0  female
# Zakarian, Mr. Mapriededer                            3         0    male
# Zakarian, Mr. Ortin                                  3         0    male
# Zimmerman, Mr. Leo                                   3         0    male
#
#                                                      age  ticket price  \
# name
# ...

# %%
#rename index and columns
element.index.name = 'index'
element.columns.name ='columns'
element
# Out:
# columns                                          class  survived     sex  \
# index
# Allen, Miss. Elisabeth Walton                        1         1  female
# Allison, Master. Hudson Trevor                       1         1    male
# Allison, Miss. Helen Loraine                         1         0  female
# Allison, Mr. Hudson Joshua Creighton                 1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)      1         0  female
# ...                                                ...       ...     ...
# Zabour, Miss. Hileni                                 3         0  female
# Zabour, Miss. Thamine                                3         0  female
# Zakarian, Mr. Mapriededer                            3         0    male
# Zakarian, Mr. Ortin                                  3         0    male
# Zimmerman, Mr. Leo                                   3         0    male
#
# columns                                              age  ticket price  \
# index
# ...

# %%
#solutions

# %%
solution = pd.read_excel('titanic3.xlsx', index_col='name')
solution
# Out:
#                                                  pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                         1         1  female
# Allison, Master. Hudson Trevor                        1         1    male
# Allison, Miss. Helen Loraine                          1         0  female
# Allison, Mr. Hudson Joshua Creighton                  1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1         0  female
# ...                                                 ...       ...     ...
# Zabour, Miss. Hileni                                  3         0  female
# Zabour, Miss. Thamine                                 3         0  female
# Zakarian, Mr. Mapriededer                             3         0    male
# Zakarian, Mr. Ortin                                   3         0    male
# Zimmerman, Mr. Leo                                    3         0    male
#
#                                                      age  sibsp  parch  \
# ...

# %%
#drop unused columns
solution.drop(columns=['home.dest', 'embarked', 'sibsp', 'parch'], inplace=True)
solution.head(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[331], line 2
#       1 #drop unused columns
# ----> 2 solution.drop(columns=['home.dest', 'embarked', 'sibsp', 'parch'], inplace=True)
#       3 solution.head(3)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
# ...

# %%
#fiter out passngers who didn survive
lived_mask = solution['survived'] == 1

solution[lived_mask]
# Out:
#                                                  pclass  survived      age  \
# name
# Allen, Miss. Elisabeth Walton                         1         1  29.0000
# Allison, Master. Hudson Trevor                        1         1   0.9167
# Anderson, Mr. Harry                                   1         1  48.0000
# Andrews, Miss. Kornelia Theodosia                     1         1  63.0000
# Appleton, Mrs. Edward Dale (Charlotte Lamson)         1         1  53.0000
# ...                                                 ...       ...      ...
# Turkula, Mrs. (Hedwig)                                3         1  63.0000
# Vartanian, Mr. David                                  3         1  22.0000
# Whabee, Mrs. George Joseph (Shawneene Abi-Saab)       3         1  38.0000
# Wilkes, Mrs. James (Ellen Needs)                      3         1  47.0000
# Yasbeck, Mrs. Antoni (Selini Alexander)               3         1  15.0000
#
# ...

# %%
solution.drop(columns=['body', 'survived'], inplace=True)
solution
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[329], line 1
# ----> 1 solution.drop(columns=['body', 'survived'], inplace=True)
#       2 solution
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
#find highest 3rd class fare
third_mask = element['pclass'] ==3
element,loc[third_mask, 'fare'].max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pclass'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[327], line 2
#       1 #find highest 3rd class fare
# ...
